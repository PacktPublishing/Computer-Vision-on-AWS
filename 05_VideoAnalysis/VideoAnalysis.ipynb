# %% [markdown]
# # Video Analysis Chapter
#
# This notebook contains snippets for interacting with the Amazon Rekognition Video API.

# %% [markdown]
# Confirm that the `boto3` module is installed.

# %%
# !pip3 install boto3
# Out:
# Requirement already satisfied: boto3 in c:\tools\python3.8\lib\site-packages (1.17.84)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in c:\tools\python3.8\lib\site-packages (from boto3) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\tools\python3.8\lib\site-packages (from boto3) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.84 in c:\tools\python3.8\lib\site-packages (from boto3) (1.20.84)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\tools\python3.8\lib\site-packages (from botocore<1.21.0,>=1.20.84->boto3) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\tools\python3.8\lib\site-packages (from botocore<1.21.0,>=1.20.84->boto3) (1.26.2)
# Requirement already satisfied: six>=1.5 in c:\tools\python3.8\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.84->boto3) (1.15.0)
# WARNING: You are using pip version 21.0; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\tools\python3.8\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# The `rtsp` module is a wrapper to the Open Computer Vision (OpenCV) library. Let's install it

# %%
# !pip3 install rtsp
# Out:
# Requirement already satisfied: rtsp in c:\tools\python3.8\lib\site-packages (1.1.8)
# Requirement already satisfied: pillow in c:\tools\python3.8\lib\site-packages (from rtsp) (8.2.0)
# Requirement already satisfied: opencv-python in c:\tools\python3.8\lib\site-packages (from rtsp) (4.5.1.48)
# Requirement already satisfied: numpy>=1.17.3 in c:\tools\python3.8\lib\site-packages (from opencv-python->rtsp) (1.20.2)
# WARNING: You are using pip version 21.0; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\tools\python3.8\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# Configure the global settings for this notebook.
#
# My eufy `base_station` is at `192.168.0.70` with username `admin` and password `EYE_SEE_YOU`. You're environment will have different properties (and hopefully a stronger password).
#
# The `cameras` dictionary maps the camera endpoint to a friendly name. You should choose names that align with your physical placement.

# %%
from rtsp import Client
base_station = 'rtsp://admin:EYE_SEE_YOU@192.168.0.70'
cameras = {
    'live0':'office',
    'live1':'kitchen',
    'live2':'living_room',    
}

# %% [markdown]
# The `get_frame` function retrieves a single image from a given camera.

# %%
from time import sleep
def get_frame(base_station, endpoint):
    rtsp_server_uri = '%s/%s' % (base_station, endpoint)
    with Client(rtsp_server_uri=rtsp_server_uri, verbose=False) as client:
        if not client.isOpened():
            print('{} server is down.'.format(rtsp_server_uri))
            return None
        else:
            print('{} server is up.'.format(rtsp_server_uri))

        while True:
            image = client.read()
            if image is None:
                sleep(0.100)
            else:
                return image
frames= {}
for endpoint in cameras.keys():
    frames[endpoint]= get_frame(base_station,endpoint)

frames
# Out:
# rtsp://admin:EYE_SEE_YOU@192.168.0.70/live0 server is up.
# rtsp://admin:EYE_SEE_YOU@192.168.0.70/live1 server is down.
# rtsp://admin:EYE_SEE_YOU@192.168.0.70/live2 server is down.
# rtsp://admin:EYE_SEE_YOU@192.168.0.70/live3 server is down.
# {'live0': <PIL.Image.Image image mode=RGB size=1920x1080>,
#  'live1': None,
#  'live2': None,
#  'live3': None}

# %% [markdown]
# You'll notice that the `fames` are Python Image Library (PIL) formatted. Let's write one to disk in PNG format.

# %%
frames['live0'].save('live0.png', format='PNG')

# %% [markdown]
# Alternatively, you can request PIL launches a window to display the image.

# %%
frames['live0'].show()

# %% [markdown]
# Next, create an Amazon S3 client and persist the `frame['live0']` into a `BytesIO` memory stream.

# %%
import boto3
region_name = 'us-east-2'
s3 = boto3.client('s3', region_name=region_name)
bucket = 'ch05-video-use2'

from io import BytesIO
frame_bytes = BytesIO()
frames['live0'].save(frame_bytes, format='PNG')

# %% [markdown]
# You can write the `frame_bytes` into S3 using the `PutObject` API.

# %%
from datetime import datetime
dt = datetime.now()
object_key = 'frames/%s/%s.png' %(
    cameras['live0'],
    dt.strftime('%Y/%m/%d/%H/%M/%S.%f')
)

response = s3.put_object(
    Bucket=bucket,
    Key=object_key,
    Body=frame_bytes.getvalue(),
    Metadata={
        'Camera': cameras['live0'],        
    })

from json import dumps
print(dumps(response, indent=2))
# Out:
# {
#   "ResponseMetadata": {
#     "RequestId": "ZAGZ8CJGEY28BJ18",
#     "HostId": "jdf5IN7y4hl52BJx4a1/iWKdBQ2hwW9FVuuKgTVZW424q+Ud5EU+LY7kjkE2ku6ZTkZtum1WBlY=",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "x-amz-id-2": "jdf5IN7y4hl52BJx4a1/iWKdBQ2hwW9FVuuKgTVZW424q+Ud5EU+LY7kjkE2ku6ZTkZtum1WBlY=",
#       "x-amz-request-id": "ZAGZ8CJGEY28BJ18",
#       "date": "Sun, 25 Dec 2022 22:10:45 GMT",
#       "etag": "\"7bddaa72bff30f00441e7fa3df9719f2\"",
#       "server": "AmazonS3",
#       "content-length": "0"
#     },
#     "RetryAttempts": 0
#   },
#   "ETag": "\"7bddaa72bff30f00441e7fa3df9719f2\""
# }

# %% [markdown]
# Amazon CloudWatch lets you create custom performance counters, called metrics. The `increment_frame_count` function will increment the metric for the `camera_name` by one.

# %%
cloudwatch = boto3.client('cloudwatch', region_name=region_name)
def increment_frame_count(camera_name, count=1):
    cloudwatch.put_metric_data(
        Namespace='VideoAnalysis',
        MetricData=[
        {
            "MetricName": 'FrameCount',
            "Value":count,
            "Unit": 'Count',
            "Dimensions": [              
                {
                    "Name": 'camera_name',
                    "Value": camera_name
                },
            ]
        }
        ]
    )

increment_frame_count(cameras['live0'])

# %% [markdown]
# Let's use the `StartPersonTracking` API to asynchronously track people within the `path_tracking_backyard.mov` file. When the processing completes a notification is sent to the `TOPIC_ARN`.
#
# To run this snippet you'll need to configure the following values:
# 1. Set the `PUBLISHER_ROLE_ARN` to the AWS IAM role containing the `PersonTrackingAssumeRole.json` policy
# 1. Set the `TOPIC_ARN` to an Amazon Simple Notification Service (Amazon SNS) topic within your account
#
# Note: If the topic doesn't start with **AmazonRekognition**, you'll need to explicitly grant the `PUBLISHER_ROLE_ARN` access to the `sns:Publish` action of the `TOPIC_ARN` resource.

# %%
import boto3
region_name='us-east-2'
bucket = 'ch05-video-use2'
rekognition = boto3.client('rekognition', region_name=region_name)


PUBLISHER_ROLE_ARN='arn:aws:iam::ACCOUNTID:role/PersonTrackingPublisher'
TOPIC_ARN='arn:aws:sns:us-east-2:ACCOUNTID:AmazonRekognitionPersonTrackingTopic'

rekognition = boto3.client('rekognition', region_name='us-east-2')

job = rekognition.start_person_tracking(
    NotificationChannel={
        'RoleArn': PUBLISHER_ROLE_ARN,
        'SNSTopicArn': TOPIC_ARN
    },
    Video={
        'S3Object':{
            'Bucket': bucket,
            'Name': 'tracking/path_tracking_backyard.mov'
        }
    })

# %% [markdown]
# Let's pretty print the `job` response from the `StartPersonTracking` API.

# %%
from json import dumps
print(dumps(job, indent=2))
# Out:
# {
#   "JobId": "117a91707136f9ab9a7212b008f6626adaa4900208bae4adac72c057d9158bc5",
#   "ResponseMetadata": {
#     "RequestId": "c0bb3572-cecb-4038-8cca-16a14816a5d7",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "x-amzn-requestid": "c0bb3572-cecb-4038-8cca-16a14816a5d7",
#       "content-type": "application/x-amz-json-1.1",
#       "content-length": "76",
#       "date": "Sun, 08 Jan 2023 15:25:15 GMT"
#     },
#     "RetryAttempts": 0
#   }
# }

# %% [markdown]
# The `get_tracking_results` utility function waits for the Person Tracking job to complete. Afterward, it'll paginate through the detections and combine them into one logical response.

# %%
from time import sleep

def get_tracking_results(jobid):
    combined_response = None
    next_token = None
    while True:
        response = rekognition.get_person_tracking(JobId=jobid)
        if response['JobStatus'] == 'IN_PROGRESS':
            print('Job %s is still running...'% jobid)
            sleep(1)
            continue
        if response['JobStatus'] == 'FAILED':
            print('Job %s is failed due to %s' %(
                jobid,
                response['StatusMessage']
            ))
            return None
        if response['JobStatus'] == 'SUCCEEDED':
            combined_response = response
            next_token = response.get('NextToken',None)
            break

    while next_token is not None:
        response = rekognition.get_person_tracking(
            JobId=jobid,
            NextToken=next_token)

        combined_response['Persons'].extend(response['Persons'])
        next_token = response.get('NextToken',None)

    return combined_response

    
get_tracking_results('117a91707136f9ab9a7212b008f6626adaa4900208bae4adac72c057d9158bc5')
# Out:
# {'JobStatus': 'SUCCEEDED',
#  'VideoMetadata': {'Codec': 'h264',
#   'DurationMillis': 19315,
#   'Format': 'QuickTime / MOV',
#   'FrameRate': 29.976701736450195,
#   'FrameHeight': 568,
#   'FrameWidth': 320,
#   'ColorRange': 'LIMITED'},
#  'Persons': [{'Timestamp': 900,
#    'Person': {'Index': 0,
#     'BoundingBox': {'Width': 0.09375,
#      'Height': 0.21830986440181732,
#      'Left': 0.90625,
#      'Top': 0.4102112650871277}}},
#   {'Timestamp': 967,
#    'Person': {'Index': 0,
#     'BoundingBox': {'Width': 0.10625000298023224,
#      'Height': 0.2042253464460373,
#      'Left': 0.890625,
#      'Top': 0.4154929518699646}}},
#   {'Timestamp': 1034,
#    'Person': {'Index': 0,
#     'BoundingBox': {'Width': 0.125,
#      'Height': 0.20246478915214539,
#      'Left': 0.871874988079071,
#      'Top': 0.4225352108478546}}},
#   {'Timestamp': 1100,
#    'Person': {'Index': 0,
#     'BoundingBox': {'Width': 0.13124999403953552,
#      'Height': 0.18485915660858154,
#      'Left': 0.8531249761581421,
#      'Top': 0.43485915660858154}}},
#   {'Timestamp': 1167,
#    'Person': {'Index': 0,
#     'BoundingBox': {'Width': 0.14374999701976776,
#      'Height': 0.18661971390247345,
#      'Left': 0.8374999761581421,
#      'Top': 0.43309858441352844}}},
#   {'Timestamp': 1234,
#    'Person': {'Index': 0,
#     'BoundingBox': {'Width': 0.18125000596046448,
#      'Height': 0.19542253017425537,
#      'Left': 0.793749988079071,
#      'Top': 0.4260563254356384}}},
#   {'Timestamp': 1301,
#    'Person': {'Index': 0,
#     'BoundingBox': {'Width': 0.17812499403953552,
#      'Height': 0.17957746982574463,
#      'Left': 0.778124988079071,
#      'Top': 0.43661972880363464}}},
#   {'Timestamp': 1367,
#    'Person': {'Index': 0,
#     'BoundingBox': {'Width': 0.16875000298023224,
#      'Height': 0.1672535240650177,
#      'Left': 0.75,
#      'Top': 0.43485915660858154}}},
#   {'Timestamp': 1434,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.13124999403953552,
#      'Height': 0.16021126508712769,
#      'Left': 0.731249988079071,
#      'Top': 0.43661972880363464}}},
#   {'Timestamp': 1567,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.13750000298023224,
#      'Height': 0.1637323945760727,
#      'Left': 0.6781250238418579,
#      'Top': 0.42781689763069153}}},
#   {'Timestamp': 1634,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.16249999403953552,
#      'Height': 0.18661971390247345,
#      'Left': 0.643750011920929,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 1701,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.19062499701976776,
#      'Height': 0.19190141558647156,
#      'Left': 0.609375,
#      'Top': 0.39788731932640076}}},
#   {'Timestamp': 1768,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.15937499701976776,
#      'Height': 0.18485915660858154,
#      'Left': 0.590624988079071,
#      'Top': 0.38732394576072693}}},
#   {'Timestamp': 1834,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.13124999403953552,
#      'Height': 0.19542253017425537,
#      'Left': 0.5718749761581421,
#      'Top': 0.3838028311729431}}},
#   {'Timestamp': 1901,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.12812499701976776,
#      'Height': 0.19014084339141846,
#      'Left': 0.5625,
#      'Top': 0.38908451795578003}}},
#   {'Timestamp': 1968,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.14374999701976776,
#      'Height': 0.17781689763069153,
#      'Left': 0.546875,
#      'Top': 0.39788731932640076}}},
#   {'Timestamp': 2034,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.171875,
#      'Height': 0.2042253464460373,
#      'Left': 0.5093749761581421,
#      'Top': 0.3785211145877838}}},
#   {'Timestamp': 2101,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.140625,
#      'Height': 0.18838028609752655,
#      'Left': 0.518750011920929,
#      'Top': 0.38908451795578003}}},
#   {'Timestamp': 2168,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.11249999701976776,
#      'Height': 0.14436618983745575,
#      'Left': 0.4906249940395355,
#      'Top': 0.42781689763069153}}},
#   {'Timestamp': 2301,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.12187500298023224,
#      'Height': 0.14260563254356384,
#      'Left': 0.44999998807907104,
#      'Top': 0.4260563254356384}}},
#   {'Timestamp': 2368,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.13124999403953552,
#      'Height': 0.14964789152145386,
#      'Left': 0.4375,
#      'Top': 0.4207746386528015}}},
#   {'Timestamp': 2435,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.13750000298023224,
#      'Height': 0.14612676203250885,
#      'Left': 0.421875,
#      'Top': 0.4190140962600708}}},
#   {'Timestamp': 2501,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.10312499850988388,
#      'Height': 0.13732394576072693,
#      'Left': 0.4156250059604645,
#      'Top': 0.42781689763069153}}},
#   {'Timestamp': 2568,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.08749999850988388,
#      'Height': 0.13204225897789001,
#      'Left': 0.4000000059604645,
#      'Top': 0.42957746982574463}}},
#   {'Timestamp': 2635,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.09375,
#      'Height': 0.13556337356567383,
#      'Left': 0.390625,
#      'Top': 0.42781689763069153}}},
#   {'Timestamp': 2768,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.11874999850988388,
#      'Height': 0.13380281627178192,
#      'Left': 0.34687501192092896,
#      'Top': 0.43309858441352844}}},
#   {'Timestamp': 2835,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.11562500149011612,
#      'Height': 0.11795774847269058,
#      'Left': 0.3375000059604645,
#      'Top': 0.43661972880363464}}},
#   {'Timestamp': 2902,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.09687499701976776,
#      'Height': 0.1267605572938919,
#      'Left': 0.3218750059604645,
#      'Top': 0.42957746982574463}}},
#   {'Timestamp': 2968,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.09062500298023224,
#      'Height': 0.128521129488945,
#      'Left': 0.30937498807907104,
#      'Top': 0.4225352108478546}}},
#   {'Timestamp': 3035,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.09375,
#      'Height': 0.1267605572938919,
#      'Left': 0.30000001192092896,
#      'Top': 0.4207746386528015}}},
#   {'Timestamp': 3102,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.10312499850988388,
#      'Height': 0.128521129488945,
#      'Left': 0.2874999940395355,
#      'Top': 0.4154929518699646}}},
#   {'Timestamp': 3169,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.10625000298023224,
#      'Height': 0.125,
#      'Left': 0.27812498807907104,
#      'Top': 0.4172535240650177}}},
#   {'Timestamp': 3235,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.08749999850988388,
#      'Height': 0.11443661898374557,
#      'Left': 0.265625,
#      'Top': 0.4225352108478546}}},
#   {'Timestamp': 3302,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.07500000298023224,
#      'Height': 0.10739436745643616,
#      'Left': 0.2562499940395355,
#      'Top': 0.43133804202079773}}},
#   {'Timestamp': 3369,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.09062500298023224,
#      'Height': 0.1232394352555275,
#      'Left': 0.23749999701976776,
#      'Top': 0.4172535240650177}}},
#   {'Timestamp': 3436,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.11249999701976776,
#      'Height': 0.11971831321716309,
#      'Left': 0.22499999403953552,
#      'Top': 0.4154929518699646}}},
#   {'Timestamp': 3502,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.11562500149011612,
#      'Height': 0.13028168678283691,
#      'Left': 0.203125,
#      'Top': 0.4084506928920746}}},
#   {'Timestamp': 3569,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.09062500298023224,
#      'Height': 0.1232394352555275,
#      'Left': 0.203125,
#      'Top': 0.4119718372821808}}},
#   {'Timestamp': 3636,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.07500000298023224,
#      'Height': 0.125,
#      'Left': 0.19374999403953552,
#      'Top': 0.4084506928920746}}},
#   {'Timestamp': 3836,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.07500000298023224,
#      'Height': 0.11091548949480057,
#      'Left': 0.16562500596046448,
#      'Top': 0.4154929518699646}}},
#   {'Timestamp': 3903,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.08124999701976776,
#      'Height': 0.10739436745643616,
#      'Left': 0.15000000596046448,
#      'Top': 0.4190140962600708}}},
#   {'Timestamp': 3969,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.07187499850988388,
#      'Height': 0.09859155118465424,
#      'Left': 0.15000000596046448,
#      'Top': 0.4225352108478546}}},
#   {'Timestamp': 4036,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.10035211592912674,
#      'Left': 0.13750000298023224,
#      'Top': 0.4207746386528015}}},
#   {'Timestamp': 4103,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.10563380271196365,
#      'Left': 0.12812499701976776,
#      'Top': 0.4172535240650177}}},
#   {'Timestamp': 4169,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.07187499850988388,
#      'Height': 0.10739436745643616,
#      'Left': 0.12187500298023224,
#      'Top': 0.4154929518699646}}},
#   {'Timestamp': 4236,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.07187499850988388,
#      'Height': 0.10739436745643616,
#      'Left': 0.11562500149011612,
#      'Top': 0.4119718372821808}}},
#   {'Timestamp': 4303,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.0625,
#      'Height': 0.09154929220676422,
#      'Left': 0.109375,
#      'Top': 0.4242957830429077}}},
#   {'Timestamp': 4503,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.10211267322301865,
#      'Left': 0.09062500298023224,
#      'Top': 0.4102112650871277}}},
#   {'Timestamp': 4570,
#    'Person': {'Index': 1,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.09859155118465424,
#      'Left': 0.08437500149011612,
#      'Top': 0.4154929518699646}}},
#   {'Timestamp': 4903,
#    'Person': {'Index': 2,
#     'BoundingBox': {'Width': 0.07500000298023224,
#      'Height': 0.11795774847269058,
#      'Left': 0.0625,
#      'Top': 0.38556337356567383}}},
#   {'Timestamp': 4970,
#    'Person': {'Index': 2,
#     'BoundingBox': {'Width': 0.07187499850988388,
#      'Height': 0.11971831321716309,
#      'Left': 0.0625,
#      'Top': 0.3838028311729431}}},
#   {'Timestamp': 5037,
#    'Person': {'Index': 2,
#     'BoundingBox': {'Width': 0.0625,
#      'Height': 0.11971831321716309,
#      'Left': 0.06562499701976776,
#      'Top': 0.38204225897789}}},
#   {'Timestamp': 5103,
#    'Person': {'Index': 2,
#     'BoundingBox': {'Width': 0.07187499850988388,
#      'Height': 0.10739436745643616,
#      'Left': 0.05937499925494194,
#      'Top': 0.3838028311729431}}},
#   {'Timestamp': 5170,
#    'Person': {'Index': 2,
#     'BoundingBox': {'Width': 0.07187499850988388,
#      'Height': 0.11443661898374557,
#      'Left': 0.05937499925494194,
#      'Top': 0.38204225897789}}},
#   {'Timestamp': 5237,
#    'Person': {'Index': 2,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.11267605423927307,
#      'Left': 0.0625,
#      'Top': 0.3802816867828369}}},
#   {'Timestamp': 5304,
#    'Person': {'Index': 2,
#     'BoundingBox': {'Width': 0.0625,
#      'Height': 0.11971831321716309,
#      'Left': 0.06562499701976776,
#      'Top': 0.375}}},
#   {'Timestamp': 5370,
#    'Person': {'Index': 2,
#     'BoundingBox': {'Width': 0.05937499925494194,
#      'Height': 0.11971831321716309,
#      'Left': 0.06875000149011612,
#      'Top': 0.3732394278049469}}},
#   {'Timestamp': 5437,
#    'Person': {'Index': 2,
#     'BoundingBox': {'Width': 0.05937499925494194,
#      'Height': 0.11795774847269058,
#      'Left': 0.06875000149011612,
#      'Top': 0.3732394278049469}}},
#   {'Timestamp': 6505,
#    'Person': {'Index': 3,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.06161971762776375,
#      'Left': 0.13124999403953552,
#      'Top': 0.4102112650871277}}},
#   {'Timestamp': 7305,
#    'Person': {'Index': 3,
#     'BoundingBox': {'Width': 0.05937499925494194,
#      'Height': 0.05809859186410904,
#      'Left': 0.22812500596046448,
#      'Top': 0.40669015049934387}}},
#   {'Timestamp': 7639,
#    'Person': {'Index': 3,
#     'BoundingBox': {'Width': 0.05937499925494194,
#      'Height': 0.056338027119636536,
#      'Left': 0.2750000059604645,
#      'Top': 0.4084506928920746}}},
#   {'Timestamp': 8039,
#    'Person': {'Index': 3,
#     'BoundingBox': {'Width': 0.05000000074505806,
#      'Height': 0.06161971762776375,
#      'Left': 0.34375,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 8106,
#    'Person': {'Index': 3,
#     'BoundingBox': {'Width': 0.046875,
#      'Height': 0.05809859186410904,
#      'Left': 0.359375,
#      'Top': 0.40492957830429077}}},
#   {'Timestamp': 8306,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.04374999925494194,
#      'Height': 0.06161971762776375,
#      'Left': 0.4000000059604645,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 8373,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.05312500149011612,
#      'Height': 0.05985915660858154,
#      'Left': 0.40625,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 8439,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.05624999850988388,
#      'Height': 0.05809859186410904,
#      'Left': 0.4156250059604645,
#      'Top': 0.40669015049934387}}},
#   {'Timestamp': 8506,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.046875,
#      'Height': 0.05809859186410904,
#      'Left': 0.4281249940395355,
#      'Top': 0.40492957830429077}}},
#   {'Timestamp': 8706,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.046875,
#      'Height': 0.06338027864694595,
#      'Left': 0.46562498807907104,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 8773,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.05312500149011612,
#      'Height': 0.06338027864694595,
#      'Left': 0.4749999940395355,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 8840,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.05000000074505806,
#      'Height': 0.05809859186410904,
#      'Left': 0.48750001192092896,
#      'Top': 0.40492957830429077}}},
#   {'Timestamp': 8973,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.04374999925494194,
#      'Height': 0.05985915660858154,
#      'Left': 0.512499988079071,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 9040,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.046875,
#      'Height': 0.05985915660858154,
#      'Left': 0.518750011920929,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 9107,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.05000000074505806,
#      'Height': 0.05985915660858154,
#      'Left': 0.528124988079071,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 9173,
#    'Person': {'Index': 4,
#     'BoundingBox': {'Width': 0.05624999850988388,
#      'Height': 0.05809859186410904,
#      'Left': 0.534375011920929,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 9307,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.42500001192092896,
#      'Height': 0.2042253464460373,
#      'Left': 0.02187499962747097,
#      'Top': 0.7922534942626953}}},
#   {'Timestamp': 9373,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.421875,
#      'Height': 0.2059859186410904,
#      'Left': 0.02187499962747097,
#      'Top': 0.7904929518699646}}},
#   {'Timestamp': 9440,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.42500001192092896,
#      'Height': 0.2077464759349823,
#      'Left': 0.02187499962747097,
#      'Top': 0.7887324094772339}}},
#   {'Timestamp': 9507,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.4281249940395355,
#      'Height': 0.2077464759349823,
#      'Left': 0.02187499962747097,
#      'Top': 0.7869718074798584}}},
#   {'Timestamp': 9574,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.4281249940395355,
#      'Height': 0.2077464759349823,
#      'Left': 0.02187499962747097,
#      'Top': 0.7887324094772339}}},
#   {'Timestamp': 9640,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.4281249940395355,
#      'Height': 0.2059859186410904,
#      'Left': 0.02187499962747097,
#      'Top': 0.7887324094772339}}},
#   {'Timestamp': 9707,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.4281249940395355,
#      'Height': 0.2042253464460373,
#      'Left': 0.02187499962747097,
#      'Top': 0.7904929518699646}}},
#   {'Timestamp': 9907,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.42500001192092896,
#      'Height': 0.2042253464460373,
#      'Left': 0.02187499962747097,
#      'Top': 0.7922534942626953}}},
#   {'Timestamp': 10041,
#    'Person': {'Index': 6,
#     'BoundingBox': {'Width': 0.109375,
#      'Height': 0.09507042169570923,
#      'Left': 0.6156250238418579,
#      'Top': 0.3697183132171631}}},
#   {'Timestamp': 10107,
#    'Person': {'Index': 6,
#     'BoundingBox': {'Width': 0.10625000298023224,
#      'Height': 0.09683098644018173,
#      'Left': 0.6187499761581421,
#      'Top': 0.36795774102211}}},
#   {'Timestamp': 10174,
#    'Person': {'Index': 6,
#     'BoundingBox': {'Width': 0.10000000149011612,
#      'Height': 0.09330985695123672,
#      'Left': 0.625,
#      'Top': 0.3714788854122162}}},
#   {'Timestamp': 10241,
#    'Person': {'Index': 6,
#     'BoundingBox': {'Width': 0.09687499701976776,
#      'Height': 0.09507042169570923,
#      'Left': 0.625,
#      'Top': 0.3714788854122162}}},
#   {'Timestamp': 10308,
#    'Person': {'Index': 6,
#     'BoundingBox': {'Width': 0.09375,
#      'Height': 0.09154929220676422,
#      'Left': 0.628125011920929,
#      'Top': 0.3732394278049469}}},
#   {'Timestamp': 10374,
#    'Person': {'Index': 6,
#     'BoundingBox': {'Width': 0.09687499701976776,
#      'Height': 0.08978873491287231,
#      'Left': 0.628125011920929,
#      'Top': 0.375}}},
#   {'Timestamp': 10574,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.43437498807907104,
#      'Height': 0.2042253464460373,
#      'Left': 0.02187499962747097,
#      'Top': 0.7940140962600708}}},
#   {'Timestamp': 10641,
#    'Person': {'Index': 6,
#     'BoundingBox': {'Width': 0.09062500298023224,
#      'Height': 0.10035211592912674,
#      'Left': 0.6312500238418579,
#      'Top': 0.3697183132171631}}},
#   {'Timestamp': 10775,
#    'Person': {'Index': 6,
#     'BoundingBox': {'Width': 0.10000000149011612,
#      'Height': 0.09507042169570923,
#      'Left': 0.6187499761581421,
#      'Top': 0.3732394278049469}}},
#   {'Timestamp': 10908,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.4281249940395355,
#      'Height': 0.2042253464460373,
#      'Left': 0.02187499962747097,
#      'Top': 0.7940140962600708}}},
#   {'Timestamp': 10975,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.4281249940395355,
#      'Height': 0.2059859186410904,
#      'Left': 0.02187499962747097,
#      'Top': 0.7904929518699646}}},
#   {'Timestamp': 11041,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.0809859186410904,
#      'Left': 0.59375,
#      'Top': 0.39612674713134766}}},
#   {'Timestamp': 11242,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.05624999850988388,
#      'Height': 0.07746478915214539,
#      'Left': 0.574999988079071,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 11308,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.4312500059604645,
#      'Height': 0.20246478915214539,
#      'Left': 0.01875000074505806,
#      'Top': 0.7940140962600708}}},
#   {'Timestamp': 11308,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.0809859186410904,
#      'Left': 0.5687500238418579,
#      'Top': 0.40492957830429077}}},
#   {'Timestamp': 11375,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.4281249940395355,
#      'Height': 0.20246478915214539,
#      'Left': 0.015625,
#      'Top': 0.7940140962600708}}},
#   {'Timestamp': 11375,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.06875000149011612,
#      'Height': 0.0809859186410904,
#      'Left': 0.559374988079071,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 11442,
#    'Person': {'Index': 5,
#     'BoundingBox': {'Width': 0.4281249940395355,
#      'Height': 0.20246478915214539,
#      'Left': 0.01875000074505806,
#      'Top': 0.7940140962600708}}},
#   {'Timestamp': 11442,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.08437500149011612,
#      'Height': 0.08626760542392731,
#      'Left': 0.543749988079071,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 11508,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.07187499850988388,
#      'Height': 0.07922535389661789,
#      'Left': 0.543749988079071,
#      'Top': 0.40669015049934387}}},
#   {'Timestamp': 11575,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.07218309491872787,
#      'Left': 0.534375011920929,
#      'Top': 0.4102112650871277}}},
#   {'Timestamp': 11709,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.07394365966320038,
#      'Left': 0.518750011920929,
#      'Top': 0.4102112650871277}}},
#   {'Timestamp': 11775,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.07187499850988388,
#      'Height': 0.07394365966320038,
#      'Left': 0.5093749761581421,
#      'Top': 0.4084506928920746}}},
#   {'Timestamp': 11909,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.0625,
#      'Height': 0.07218309491872787,
#      'Left': 0.4906249940395355,
#      'Top': 0.40669015049934387}}},
#   {'Timestamp': 11975,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.05312500149011612,
#      'Height': 0.07394365966320038,
#      'Left': 0.484375,
#      'Top': 0.4084506928920746}}},
#   {'Timestamp': 12042,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.06875000149011612,
#      'Height': 0.07922535389661789,
#      'Left': 0.46875,
#      'Top': 0.40669015049934387}}},
#   {'Timestamp': 12109,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.08437500149011612,
#      'Height': 0.09859155118465424,
#      'Left': 0.45625001192092896,
#      'Top': 0.38732394576072693}}},
#   {'Timestamp': 12176,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.09062500298023224,
#      'Height': 0.08978873491287231,
#      'Left': 0.4468750059604645,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 12309,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.0625,
#      'Height': 0.0809859186410904,
#      'Left': 0.43437498807907104,
#      'Top': 0.4084506928920746}}},
#   {'Timestamp': 12376,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.0625,
#      'Height': 0.0845070406794548,
#      'Left': 0.4281249940395355,
#      'Top': 0.40669015049934387}}},
#   {'Timestamp': 12442,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.078125,
#      'Height': 0.09507042169570923,
#      'Left': 0.4124999940395355,
#      'Top': 0.39788731932640076}}},
#   {'Timestamp': 12509,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.09062500298023224,
#      'Height': 0.09859155118465424,
#      'Left': 0.3968749940395355,
#      'Top': 0.39788731932640076}}},
#   {'Timestamp': 12576,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.08437500149011612,
#      'Height': 0.09683098644018173,
#      'Left': 0.38749998807907104,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 12776,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.09375,
#      'Height': 0.09507042169570923,
#      'Left': 0.3531250059604645,
#      'Top': 0.39612674713134766}}},
#   {'Timestamp': 12843,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.10312499850988388,
#      'Height': 0.11091548949480057,
#      'Left': 0.34687501192092896,
#      'Top': 0.38732394576072693}}},
#   {'Timestamp': 12976,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.09687499701976776,
#      'Height': 0.09683098644018173,
#      'Left': 0.328125,
#      'Top': 0.39436620473861694}}},
#   {'Timestamp': 13176,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.08124999701976776,
#      'Height': 0.10563380271196365,
#      'Left': 0.3031249940395355,
#      'Top': 0.39612674713134766}}},
#   {'Timestamp': 13243,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.08749999850988388,
#      'Height': 0.10211267322301865,
#      'Left': 0.29374998807907104,
#      'Top': 0.39788731932640076}}},
#   {'Timestamp': 13310,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.09375,
#      'Height': 0.11443661898374557,
#      'Left': 0.28125,
#      'Top': 0.39260563254356384}}},
#   {'Timestamp': 13377,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.06875000149011612,
#      'Height': 0.10739436745643616,
#      'Left': 0.28125,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 13443,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.0625,
#      'Height': 0.10387323796749115,
#      'Left': 0.2750000059604645,
#      'Top': 0.4084506928920746}}},
#   {'Timestamp': 13510,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.06562499701976776,
#      'Height': 0.10211267322301865,
#      'Left': 0.265625,
#      'Top': 0.40669015049934387}}},
#   {'Timestamp': 13643,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.08749999850988388,
#      'Height': 0.13028168678283691,
#      'Left': 0.234375,
#      'Top': 0.38732394576072693}}},
#   {'Timestamp': 13710,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.09062500298023224,
#      'Height': 0.11971831321716309,
#      'Left': 0.22499999403953552,
#      'Top': 0.39612674713134766}}},
#   {'Timestamp': 13777,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.08124999701976776,
#      'Height': 0.11443661898374557,
#      'Left': 0.21875,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 13844,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.10000000149011612,
#      'Height': 0.11267605423927307,
#      'Left': 0.20000000298023224,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 13910,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.109375,
#      'Height': 0.12147887051105499,
#      'Left': 0.1875,
#      'Top': 0.39612674713134766}}},
#   {'Timestamp': 13977,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.10312499850988388,
#      'Height': 0.1232394352555275,
#      'Left': 0.18437500298023224,
#      'Top': 0.39788731932640076}}},
#   {'Timestamp': 14044,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.10625000298023224,
#      'Height': 0.13204225897789001,
#      'Left': 0.171875,
#      'Top': 0.39612674713134766}}},
#   {'Timestamp': 14110,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.09375,
#      'Height': 0.1232394352555275,
#      'Left': 0.16249999403953552,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 14177,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.10312499850988388,
#      'Height': 0.11795774847269058,
#      'Left': 0.14374999701976776,
#      'Top': 0.4102112650871277}}},
#   {'Timestamp': 14244,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.10312499850988388,
#      'Height': 0.11619718372821808,
#      'Left': 0.13437500596046448,
#      'Top': 0.40669015049934387}}},
#   {'Timestamp': 14311,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.08437500149011612,
#      'Height': 0.1232394352555275,
#      'Left': 0.13750000298023224,
#      'Top': 0.40316900610923767}}},
#   {'Timestamp': 14377,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.09375,
#      'Height': 0.13028168678283691,
#      'Left': 0.11874999850988388,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 14444,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.08437500149011612,
#      'Height': 0.13732394576072693,
#      'Left': 0.11562500149011612,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 14511,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.10000000149011612,
#      'Height': 0.13204225897789001,
#      'Left': 0.10000000149011612,
#      'Top': 0.4102112650871277}}},
#   {'Timestamp': 14577,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.109375,
#      'Height': 0.128521129488945,
#      'Left': 0.08749999850988388,
#      'Top': 0.4172535240650177}}},
#   {'Timestamp': 14644,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.12812499701976776,
#      'Height': 0.13380281627178192,
#      'Left': 0.07500000298023224,
#      'Top': 0.4119718372821808}}},
#   {'Timestamp': 14711,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.12187500298023224,
#      'Height': 0.14788731932640076,
#      'Left': 0.07500000298023224,
#      'Top': 0.4084506928920746}}},
#   {'Timestamp': 14778,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.13750000298023224,
#      'Height': 0.14788731932640076,
#      'Left': 0.05312500149011612,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 14844,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.14374999701976776,
#      'Height': 0.15669013559818268,
#      'Left': 0.04374999925494194,
#      'Top': 0.40140846371650696}}},
#   {'Timestamp': 14911,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.140625,
#      'Height': 0.15140844881534576,
#      'Left': 0.04062499850988388,
#      'Top': 0.4102112650871277}}},
#   {'Timestamp': 14978,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.15000000596046448,
#      'Height': 0.15140844881534576,
#      'Left': 0.03437500074505806,
#      'Top': 0.4137323796749115}}},
#   {'Timestamp': 15045,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.140625,
#      'Height': 0.15140844881534576,
#      'Left': 0.04062499850988388,
#      'Top': 0.4137323796749115}}},
#   {'Timestamp': 15111,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.14374999701976776,
#      'Height': 0.1672535240650177,
#      'Left': 0.03750000149011612,
#      'Top': 0.40492957830429077}}},
#   {'Timestamp': 15178,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.14687499403953552,
#      'Height': 0.18309858441352844,
#      'Left': 0.03750000149011612,
#      'Top': 0.39964789152145386}}},
#   {'Timestamp': 15245,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.140625,
#      'Height': 0.18838028609752655,
#      'Left': 0.046875,
#      'Top': 0.40669015049934387}}},
#   {'Timestamp': 15311,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.14687499403953552,
#      'Height': 0.17781689763069153,
#      'Left': 0.04062499850988388,
#      'Top': 0.4190140962600708}}},
#   {'Timestamp': 15378,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.13750000298023224,
#      'Height': 0.1690140813589096,
#      'Left': 0.046875,
#      'Top': 0.4225352108478546}}},
#   {'Timestamp': 15445,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.13124999403953552,
#      'Height': 0.17957746982574463,
#      'Left': 0.06562499701976776,
#      'Top': 0.4207746386528015}}},
#   {'Timestamp': 15512,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.13750000298023224,
#      'Height': 0.20070423185825348,
#      'Left': 0.06875000149011612,
#      'Top': 0.4137323796749115}}},
#   {'Timestamp': 15578,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.13437500596046448,
#      'Height': 0.2130281627178192,
#      'Left': 0.08124999701976776,
#      'Top': 0.4084506928920746}}},
#   {'Timestamp': 15645,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.14374999701976776,
#      'Height': 0.2130281627178192,
#      'Left': 0.08749999850988388,
#      'Top': 0.4137323796749115}}},
#   {'Timestamp': 15712,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.16249999403953552,
#      'Height': 0.19894365966320038,
#      'Left': 0.08437500149011612,
#      'Top': 0.4225352108478546}}},
#   {'Timestamp': 15778,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.171875,
#      'Height': 0.19366197288036346,
#      'Left': 0.09375,
#      'Top': 0.42957746982574463}}},
#   {'Timestamp': 15845,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.17812499403953552,
#      'Height': 0.19542253017425537,
#      'Left': 0.10312499850988388,
#      'Top': 0.42781689763069153}}},
#   {'Timestamp': 15912,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.17499999701976776,
#      'Height': 0.21478873491287231,
#      'Left': 0.11874999850988388,
#      'Top': 0.4225352108478546}}},
#   {'Timestamp': 15979,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.17812499403953552,
#      'Height': 0.21654929220676422,
#      'Left': 0.12812499701976776,
#      'Top': 0.4172535240650177}}},
#   {'Timestamp': 16045,
#    'Person': {'Index': 7,
#     'BoundingBox': {'Width': 0.17499999701976776,
#      'Height': 0.22535210847854614,
#      'Left': 0.140625,
#      'Top': 0.4260563254356384}}},
#   {'Timestamp': 16112,
#    'Person': {'Index': 8,
#     'BoundingBox': {'Width': 0.17499999701976776,
#      'Height': 0.23239436745643616,
#      'Left': 0.15625,
#      'Top': 0.44014084339141846}}},
#   {'Timestamp': 16179,
#    'Person': {'Index': 8,
#     'BoundingBox': {'Width': 0.17499999701976776,
#      'Height': 0.22359155118465424,
#      'Left': 0.171875,
#      'Top': 0.4489436745643616}}},
#   {'Timestamp': 16245,
#    'Person': {'Index': 8,
#     'BoundingBox': {'Width': 0.171875,
#      'Height': 0.21654929220676422,
#      'Left': 0.1875,
#      'Top': 0.4507042169570923}}},
#   {'Timestamp': 16312,
#    'Person': {'Index': 8,
#     'BoundingBox': {'Width': 0.16562500596046448,
#      'Height': 0.23767605423927307,
#      'Left': 0.21250000596046448,
#      'Top': 0.44542253017425537}}},
#   {'Timestamp': 16379,
#    'Person': {'Index': 8,
#     'BoundingBox': {'Width': 0.16562500596046448,
#      'Height': 0.27640846371650696,
#      'Left': 0.23749999701976776,
#      'Top': 0.42781689763069153}}},
#   {'Timestamp': 16446,
#    'Person': {'Index': 8,
#     'BoundingBox': {'Width': 0.19687500596046448,
#      'Height': 0.2869718372821808,
#      'Left': 0.23749999701976776,
#      'Top': 0.43661972880363464}}},
#   {'Timestamp': 16512,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.21562500298023224,
#      'Height': 0.2904929518699646,
#      'Left': 0.23749999701976776,
#      'Top': 0.43485915660858154}}},
#   {'Timestamp': 16579,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.20937499403953552,
#      'Height': 0.2904929518699646,
#      'Left': 0.2593750059604645,
#      'Top': 0.44190141558647156}}},
#   {'Timestamp': 16646,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.203125,
#      'Height': 0.27816900610923767,
#      'Left': 0.2874999940395355,
#      'Top': 0.4559859037399292}}},
#   {'Timestamp': 16712,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.20624999701976776,
#      'Height': 0.2922535240650177,
#      'Left': 0.3187499940395355,
#      'Top': 0.4524647891521454}}},
#   {'Timestamp': 16779,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.24375000596046448,
#      'Height': 0.32042253017425537,
#      'Left': 0.3218750059604645,
#      'Top': 0.4507042169570923}}},
#   {'Timestamp': 16846,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.25312501192092896,
#      'Height': 0.3309859037399292,
#      'Left': 0.3375000059604645,
#      'Top': 0.4507042169570923}}},
#   {'Timestamp': 16913,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.2562499940395355,
#      'Height': 0.35563379526138306,
#      'Left': 0.34375,
#      'Top': 0.4489436745643616}}},
#   {'Timestamp': 16979,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.28437501192092896,
#      'Height': 0.35387325286865234,
#      'Left': 0.34687501192092896,
#      'Top': 0.4542253613471985}}},
#   {'Timestamp': 17046,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.2906250059604645,
#      'Height': 0.3661971688270569,
#      'Left': 0.36250001192092896,
#      'Top': 0.4559859037399292}}},
#   {'Timestamp': 17113,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.28437501192092896,
#      'Height': 0.3397887349128723,
#      'Left': 0.4000000059604645,
#      'Top': 0.47007042169570923}}},
#   {'Timestamp': 17180,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.2718749940395355,
#      'Height': 0.3397887349128723,
#      'Left': 0.4375,
#      'Top': 0.4647887349128723}}},
#   {'Timestamp': 17246,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.26249998807907104,
#      'Height': 0.35387325286865234,
#      'Left': 0.46875,
#      'Top': 0.4665493071079254}}},
#   {'Timestamp': 17313,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.27812498807907104,
#      'Height': 0.3714788854122162,
#      'Left': 0.4906249940395355,
#      'Top': 0.4595070481300354}}},
#   {'Timestamp': 17380,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.30937498807907104,
#      'Height': 0.38204225897789,
#      'Left': 0.5062500238418579,
#      'Top': 0.4559859037399292}}},
#   {'Timestamp': 17446,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3656249940395355,
#      'Height': 0.46830984950065613,
#      'Left': 0.5218750238418579,
#      'Top': 0.47359153628349304}}},
#   {'Timestamp': 17513,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.40312498807907104,
#      'Height': 0.5,
#      'Left': 0.5062500238418579,
#      'Top': 0.47535210847854614}}},
#   {'Timestamp': 17580,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3218750059604645,
#      'Height': 0.46830984950065613,
#      'Left': 0.5874999761581421,
#      'Top': 0.48239436745643616}}},
#   {'Timestamp': 17647,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.34062498807907104,
#      'Height': 0.48943662643432617,
#      'Left': 0.606249988079071,
#      'Top': 0.46830984950065613}}},
#   {'Timestamp': 17713,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3656249940395355,
#      'Height': 0.5017605423927307,
#      'Left': 0.609375,
#      'Top': 0.4612676203250885}}},
#   {'Timestamp': 17780,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3687500059604645,
#      'Height': 0.5211267471313477,
#      'Left': 0.625,
#      'Top': 0.4612676203250885}}},
#   {'Timestamp': 17847,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.35624998807907104,
#      'Height': 0.5369718074798584,
#      'Left': 0.643750011920929,
#      'Top': 0.4577464759349823}}},
#   {'Timestamp': 17913,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.34687501192092896,
#      'Height': 0.5369718074798584,
#      'Left': 0.653124988079071,
#      'Top': 0.4630281627178192}}},
#   {'Timestamp': 17980,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.34062498807907104,
#      'Height': 0.5228873491287231,
#      'Left': 0.659375011920929,
#      'Top': 0.47535210847854614}}},
#   {'Timestamp': 18047,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3343749940395355,
#      'Height': 0.5158450603485107,
#      'Left': 0.6625000238418579,
#      'Top': 0.47711268067359924}}},
#   {'Timestamp': 18114,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.33125001192092896,
#      'Height': 0.5193662047386169,
#      'Left': 0.6656249761581421,
#      'Top': 0.47887325286865234}}},
#   {'Timestamp': 18180,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.30937498807907104,
#      'Height': 0.5158450603485107,
#      'Left': 0.690625011920929,
#      'Top': 0.48239436745643616}}},
#   {'Timestamp': 18247,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.30937498807907104,
#      'Height': 0.5211267471313477,
#      'Left': 0.690625011920929,
#      'Top': 0.47887325286865234}}},
#   {'Timestamp': 18314,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3062500059604645,
#      'Height': 0.5211267471313477,
#      'Left': 0.6937500238418579,
#      'Top': 0.47535210847854614}}},
#   {'Timestamp': 18380,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.31562501192092896,
#      'Height': 0.5211267471313477,
#      'Left': 0.6812499761581421,
#      'Top': 0.47711268067359924}}},
#   {'Timestamp': 18447,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3187499940395355,
#      'Height': 0.51408451795578,
#      'Left': 0.6781250238418579,
#      'Top': 0.48415493965148926}}},
#   {'Timestamp': 18514,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.31562501192092896,
#      'Height': 0.48767605423927307,
#      'Left': 0.6812499761581421,
#      'Top': 0.5}}},
#   {'Timestamp': 18581,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3125,
#      'Height': 0.48415493965148926,
#      'Left': 0.6812499761581421,
#      'Top': 0.5070422291755676}}},
#   {'Timestamp': 18647,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3187499940395355,
#      'Height': 0.48767605423927307,
#      'Left': 0.6781250238418579,
#      'Top': 0.5052816867828369}}},
#   {'Timestamp': 18714,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3375000059604645,
#      'Height': 0.48591548204421997,
#      'Left': 0.6625000238418579,
#      'Top': 0.5}}},
#   {'Timestamp': 18781,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.34687501192092896,
#      'Height': 0.48415493965148926,
#      'Left': 0.6499999761581421,
#      'Top': 0.5017605423927307}}},
#   {'Timestamp': 18847,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.35624998807907104,
#      'Height': 0.4911971688270569,
#      'Left': 0.643750011920929,
#      'Top': 0.4982394278049469}}},
#   {'Timestamp': 18914,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.3656249940395355,
#      'Height': 0.4982394278049469,
#      'Left': 0.6343749761581421,
#      'Top': 0.4982394278049469}}},
#   {'Timestamp': 18981,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.4000000059604645,
#      'Height': 0.48767605423927307,
#      'Left': 0.6000000238418579,
#      'Top': 0.5123239159584045}}},
#   {'Timestamp': 19048,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.42500001192092896,
#      'Height': 0.48415493965148926,
#      'Left': 0.574999988079071,
#      'Top': 0.5158450603485107}}},
#   {'Timestamp': 19114,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.4468750059604645,
#      'Height': 0.47711268067359924,
#      'Left': 0.5406249761581421,
#      'Top': 0.5228873491287231}}},
#   {'Timestamp': 19181,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.48750001192092896,
#      'Height': 0.47359153628349304,
#      'Left': 0.5,
#      'Top': 0.5264084339141846},
#     'Face': {'BoundingBox': {'Width': 0.16580438613891602,
#       'Height': 0.1224595159292221,
#       'Left': 0.7638211250305176,
#       'Top': 0.6031092405319214},
#      'Landmarks': [{'Type': 'eyeLeft',
#        'X': 0.8067267537117004,
#        'Y': 0.6486892104148865},
#       {'Type': 'eyeRight', 'X': 0.87501460313797, 'Y': 0.6515184044837952},
#       {'Type': 'mouthLeft', 'X': 0.8094583749771118, 'Y': 0.6903133988380432},
#       {'Type': 'mouthRight', 'X': 0.8667328953742981, 'Y': 0.6927722096443176},
#       {'Type': 'nose', 'X': 0.8352755308151245, 'Y': 0.6779088973999023}],
#      'Pose': {'Roll': 4.322456359863281,
#       'Yaw': -3.314725399017334,
#       'Pitch': -5.2167887687683105},
#      'Quality': {'Brightness': 39.75089645385742,
#       'Sharpness': 3.3018569946289062},
#      'Confidence': 99.9489517211914}}},
#   {'Timestamp': 19248,
#    'Person': {'Index': 9,
#     'BoundingBox': {'Width': 0.53125,
#      'Height': 0.4665493071079254,
#      'Left': 0.46875,
#      'Top': 0.5299295783042908}}}],
#  'ResponseMetadata': {'RequestId': 'a5465195-27fa-4a1a-9bc4-594e49079630',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'a5465195-27fa-4a1a-9bc4-594e49079630',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '34296',
#    'date': 'Sun, 08 Jan 2023 19:05:34 GMT'},
#   'RetryAttempts': 0}}

# %%
tracking_results = get_tracking_results('117a91707136f9ab9a7212b008f6626adaa4900208bae4adac72c057d9158bc5')
#tracking_results['Persons'][0]

# %% [markdown]
# Let's map the `tracking_results` back to the originating video. Use the OpenCV `VideoCapture` class to open **MOV** and related formatted files.

# %%
from cv2 import VideoCapture
capture = VideoCapture('tracking/path_tracking_backyard.mov')

# %% [markdown]
# You can select a specific frame from the video by setting the `CAP_PROP_POS_MSEC` property. This example seeks to the 900ms and gets the `result` and `frame`. If the operation is successful `result` will be **True** and `frame` is not **None**.

# %%
from cv2 import CAP_PROP_POS_MSEC
capture.set(CAP_PROP_POS_MSEC, 900)
result, frame = capture.read()

# %% [markdown]
# You can use get person detection offsets from the `tracking_results` response.

# %%
from cv2 import VideoCapture
from PIL import Image
capture = VideoCapture('tracking/path_tracking_backyard.mov')

first_detection = None
for detection in tracking_results['Persons']:
    if 'Face' in detection['Person']:
        first_detection = detection
        break

capture.set(CAP_PROP_POS_MSEC, first_detection['Timestamp'])
res, frame = capture.read()

image = Image.fromarray(frame)
image.show()

# %% [markdown]
# The `PersonDetection` object specifies a `BoundingBox` around the person. Let's draw a red rectangle around the finding.

# %%
def denormalize_bounding_box(bounding_box, image_size):
    width = int(bounding_box['Width'] * image_size[0])
    left = int(bounding_box['Left'] * image_size[0])

    height = int(bounding_box['Height'] * image_size[1])
    top = int(bounding_box['Top'] * image_size[1])
    return (top,left,height,width)

from PIL import Image, ImageDraw
image = Image.fromarray(frame)

(top,left,height,width) = denormalize_bounding_box(
    first_detection['Person']['BoundingBox'],
    image.size)

drawing = ImageDraw.Draw(image)
drawing.rectangle(
    xy=(left,top,left+width, left+height),
    outline='red',
    width=5)

image.save('tracking/ViewFrame.jpeg',format='JPEG')
image.show()

# %% [markdown]
# When you're finished processing the video, use the `release` method to free the underlying resources.

# %%
capture.release()
print('The capture variable is %s' % capture.isOpened())
# Out:
# The capture variable is False
